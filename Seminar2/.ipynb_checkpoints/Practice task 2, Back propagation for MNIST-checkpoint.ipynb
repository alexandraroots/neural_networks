# %% [markdown]
# ## Семинар 2 "Распознавание рукописных цифр"

# %% [markdown]
# ФИО: Корнеева Александра Михайловна

# %% [markdown]
# В этом задании мы используем нейронную сеть из предыдущего семинара для распознавания рукописных цифр. Также мы исследуем как влияет выбор нелинейности и предобработка данных на качество классификации.
#
# Чтобы не тратить время на подготовку данных, мы прилагаем готовый код с примером использования для получения обучающей и тестовой выборок. Для запуска скрипта вам понадобится библиотека PyTorch (инструкции по установке можно найти на сайте <a href="http://pytorch.org">pytorch.org</a>)

# %%
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
from torchvision.datasets import MNIST
from torchvision import transforms
import numpy as np
import sys
from layers import Linear, Sigmoid, NLLLoss, NeuralNetwork # Results from Seminar 1
from IPython.display import clear_output
# %matplotlib inline

# %%
transform = transforms.Compose([
                       transforms.ToTensor(),
                       transforms.Normalize((0.1307,), (0.3081,))
                    ])
train_dataset = MNIST('.', train=True, download=True, transform=transform)
test_dataset = MNIST('.', train=False, transform=transform)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=True)

# %%
## Usage example:
for X, y in train_loader:
    X = X.view(X.shape[0], -1)
    X = X.numpy() ### Converts torch.Tensor to numpy array
    y = y.numpy()
    pass

# %%
plt.figure(figsize=(6, 7))
for i in range(25):
    plt.subplot(5, 5, i+1)
    plt.imshow(X[i].reshape(28, 28), cmap=plt.cm.Greys_r)
    plt.title(y[i])
    plt.axis('off')

# %% [markdown]
# ### Часть 1: MNIST
# Обучите полносвязную нейронную сеть с архитектурой 784-100-100-10 и сигмоидой в качестве нелинейности. Какую точность классификации удалось получить? Нарисуйте график сходимости на обучающей и тестовой выборках. В качестве темпа обучения (learning rate) возьмите 0.01

# %%
def train(network, epochs, learning_rate, plot=True, verbose=True, loss=None):
    loss = loss or NLLLoss()
    train_loss_epochs = []
    test_loss_epochs = []
    train_accuracy_epochs = []
    test_accuracy_epochs = []
    try:
        for epoch in range(epochs):
            losses = []
            accuracies = []
            for X, y in train_loader:
                X = X.view(X.shape[0], -1).numpy()
                y = y.numpy()
                prediction = network.forward(X)
                loss_batch = loss.forward(prediction, y)
                losses.append(loss_batch)
                dLdx = loss.backward()
                network.backward(dLdx)
                network.step(learning_rate)
                accuracies.append((np.argmax(prediction, 1)==y).mean())
            train_loss_epochs.append(np.mean(losses))
            train_accuracy_epochs.append(np.mean(accuracies))
            losses = []
            accuracies = []    
            for X, y in test_loader:
                X = X.view(X.shape[0], -1).numpy()
                y = y.numpy()
                prediction = network.forward(X)
                loss_batch = loss.forward(prediction, y)
                losses.append(loss_batch)
                accuracies.append((np.argmax(prediction, 1)==y).mean())
            test_loss_epochs.append(np.mean(losses))
            test_accuracy_epochs.append(np.mean(accuracies))
            clear_output(True)
            if verbose:
                sys.stdout.write('\rEpoch {0}... (Train/Test) NLL: {1:.3f}/{2:.3f}\tAccuracy: {3:.3f}/{4:.3f}'.format(
                            epoch, train_loss_epochs[-1], test_loss_epochs[-1],
                            train_accuracy_epochs[-1], test_accuracy_epochs[-1]))
            if plot:
                plt.figure(figsize=(12, 5))
                plt.subplot(1, 2, 1)
                plt.plot(train_loss_epochs, label='Train')
                plt.plot(test_loss_epochs, label='Test')
                plt.xlabel('Epochs', fontsize=16)
                plt.ylabel('Loss', fontsize=16)
                plt.legend(loc=0, fontsize=16)
                plt.grid('on')
                plt.subplot(1, 2, 2)
                plt.plot(train_accuracy_epochs, label='Train accuracy')
                plt.plot(test_accuracy_epochs, label='Test accuracy')
                plt.xlabel('Epochs', fontsize=16)
                plt.ylabel('Loss', fontsize=16)
                plt.legend(loc=0, fontsize=16)
                plt.grid('on')
                plt.show()
    except KeyboardInterrupt:
        pass
    return train_loss_epochs, \
           test_loss_epochs, \
           train_accuracy_epochs, \
           test_accuracy_epochs

# %%
network = NeuralNetwork([Linear(784, 100), Sigmoid(),
               Linear(100, 100), Sigmoid(),
               Linear(100, 10)])
loss = NLLLoss()

# %%
tr_s, ts_s, tr_ac_s, ts_ac_s = train(network, 20, 0.01)
# Out:
# Epoch 19... (Train/Test) NLL: 0.302/0.297	Accuracy: 0.921/0.921

# %% [markdown]
# ### Часть 2: Нелинейности

# %% [markdown]
# Обучите нейронную сеть с другими нелинейностями: ReLU и ELU. Сравните скорости сходимости и качество классификации с различными функциями активации.

# %%
class ReLU:
    def __init__(self):
        pass

    def forward(self, X):
        '''
        Passes objects through this layer.
        X is np.array of size (N, d)
        '''
        self.X = X
        return np.maximum(X, 0)

    def backward(self, dLdy):
        '''
        1. Compute dLdx.
        2. Return dLdx
        '''
        dydX = (self.X >= 0).astype(float)
        return dLdy*dydX

    def step(self, learning_rate):
        pass

# %%
class ELU:
    '''
    ELU(x) = x, x > 0; a*(e^x - 1), x <= 0
    '''
    
    def __init__(self, a=1):
        self.a = a

    def forward(self, X):
        '''
        Passes objects through this layer.
        X is np.array of size (N, d)
        '''
        self.X = X
        return X * (X > 0) + self.a * (np.exp(X) - 1) * (X <= 0)
    
    def backward(self, dLdy):
        '''
        1. Compute dLdx.
        2. Return dLdx
        '''
        X = self.X
        dydX = (X > 0) + self.a * np.exp(X) * (X <= 0)
        return dLdy*dydX

    def step(self, learning_rate):
        pass

# %%
network = NeuralNetwork([Linear(784, 100), ReLU(),
               Linear(100, 100), ReLU(),
               Linear(100, 10)])
loss = NLLLoss()
tr_r, ts_r, tr_ac_r, ts_ac_r = train(network, 20, 0.01, plot=False, verbose=False)

# %%
network = NeuralNetwork([Linear(784, 100), ELU(),
               Linear(100, 100), ELU(),
               Linear(100, 10)])
loss = NLLLoss()
tr_e, ts_e, tr_ac_e, ts_ac_e = train(network, 20, 0.01, plot=False, verbose=False)

# %%
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.title('Loss')
plt.plot(ts_s, label='Sigmoid')
plt.plot(ts_r, label='ReLU')
plt.plot(ts_e, label='ELU')
plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Loss', fontsize=16)
plt.legend(loc=0, fontsize=16)
plt.grid()
plt.subplot(1, 2, 2)
plt.title('Accuracy')
plt.plot(ts_ac_s, label='Sigmoid')
plt.plot(ts_ac_r, label='ReLU')
plt.plot(ts_ac_e, label='ELU')
plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Loss', fontsize=16)
plt.legend(loc=0, fontsize=16)
plt.grid()
plt.show()

# %% [markdown]
# ### Часть 3: Анализ ошибок
# На каких объектах сеть ошибается больше всего?

# %%
wrong_X = []
correct_y = []
predicted_y = []
logits = []
for X, y in test_loader:
    X = X.view(X.shape[0], -1).numpy()
    y = y.numpy()
    prediction = network.forward(X)
    prediction = np.exp(prediction)
    prediction /= prediction.sum(1, keepdims=True)
    for i in range(len(prediction)):
        if np.argmax(prediction[i]) != y[i]:
            wrong_X.append(X[i])
            correct_y.append(y[i])
            predicted_y.append(np.argmax(prediction[i]))
            logits.append(prediction[i][y[i]])
wrong_X = np.row_stack(wrong_X)
correct_y = np.row_stack(correct_y)[:, 0]
predicted_y = np.row_stack(predicted_y)[:, 0]
logits = np.row_stack(logits)[:, 0]

# %%
plt.figure(figsize=(10, 5))
order = np.argsort(logits)
for i in range(21):
    plt.subplot(3, 7, i+1)
    plt.imshow(wrong_X[order[i]].reshape(28, 28), cmap=plt.cm.Greys_r)
    plt.title('{}({})'.format(correct_y[order[i]], predicted_y[order[i]]), fontsize=20)
    plt.axis('off')

# %% [markdown]
# ### HW1 (1 балл): Реализовать Tanh

# %%
class TANH:

    def __init__(self, a=1):
        pass

    def forward(self, X):

        self.X = X
        return (np.exp(2 * X) - 1) / (np.exp(2 * X) + 1)
    
    def backward(self, dLdy):

        X = self.X
        cosh = (np.exp(X) + np.exp(-X))
        dydX = 4 / (cosh * cosh)
        return dLdy * dydX

    def step(self, learning_rate):
        pass

# %%
network = NeuralNetwork([Linear(784, 100), TANH(),
               Linear(100, 100), TANH(),
               Linear(100, 10)])
loss = NLLLoss()

# %%
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.title('Loss')
plt.plot(ts_t, label='TANH')
plt.plot(ts_s, label='Sigmoid')
plt.plot(ts_r, label='ReLU')
plt.plot(ts_e, label='ELU')
plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Loss', fontsize=16)
plt.legend(loc=0, fontsize=16)
plt.grid()
plt.subplot(1, 2, 2)
plt.title('Accuracy')
plt.plot(ts_ac_t, label='TANH')
plt.plot(ts_ac_s, label='Sigmoid')
plt.plot(ts_ac_r, label='ReLU')
plt.plot(ts_ac_e, label='ELU')
plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Loss', fontsize=16)
plt.legend(loc=0, fontsize=16)
plt.grid()
plt.show()

# %% [markdown]
# ### Часть 4: Аугментация (HW, 2 балла)
# * Небольшие вращения (-15, 15)
# * Случайные сдвиги
# * Шум
#
# Какой прирост дают эти аугментации вместе и по отдельности

# %% [markdown]
# Вращение:

# %%
transform_rotation = transforms.Compose([
                       transforms.RandomRotation((-15, 15)),
                       transforms.ToTensor(),
                       transforms.Normalize((0.1307,), (0.3081,))
                    ])

# %%
train_dataset = MNIST('.', train=True, download=True, transform=transform_rotation)
test_dataset = MNIST('.', train=False, transform=transform_rotation)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=True)

network = NeuralNetwork([Linear(784, 100), TANH(),
               Linear(100, 100), TANH(),
               Linear(100, 10)])
loss = NLLLoss()

# %%
tr_t_r, ts_t_r, tr_ac_t_r, ts_ac_t_r = train(network, 20, 0.01)
# Out:
# Epoch 19... (Train/Test) NLL: 0.067/0.078	Accuracy: 0.980/0.975

# %% [markdown]
# Сдвиг:

# %%
transform_affine = transforms.Compose([
                       transforms.RandomAffine(0, translate=(0.15, 0.15)),
                       transforms.ToTensor(),
                       transforms.Normalize((0.1307,), (0.3081,))
                    ])

# %%
train_dataset = MNIST('.', train=True, download=True, transform=transform_affine)
test_dataset = MNIST('.', train=False, transform=transform_affine)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=True)

network = NeuralNetwork([Linear(784, 100), TANH(),
               Linear(100, 100), TANH(),
               Linear(100, 10)])
loss = NLLLoss()

# %%
tr_t_a, ts_t_a, tr_ac_t_a, ts_ac_t_a = train(network, 20, 0.01)
# Out:
# Epoch 19... (Train/Test) NLL: 0.162/0.155	Accuracy: 0.950/0.952

# %% [markdown]
# Шум:

# %%
import torch
from skimage.util import random_noise

def noise(img):
    return torch.from_numpy(random_noise(img.numpy().reshape(28, 28).astype(np.float)))

# %%
transform_noise = transforms.Compose([
                       transforms.ToTensor(),
                       transforms.Normalize((0.1307,), (0.3081,))
                    ] + [noise])

# %%
train_dataset = MNIST('.', train=True, download=True, transform=transform_noise)
test_dataset = MNIST('.', train=False, transform=transform_noise)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=True)

network = NeuralNetwork([Linear(784, 100), TANH(),
               Linear(100, 100), TANH(),
               Linear(100, 10)])
loss = NLLLoss()

# %%
tr_t_n, ts_t_n, tr_ac_t_n, ts_ac_t_n = train(network, 20, 0.01)
# Out:
# Epoch 19... (Train/Test) NLL: 0.068/0.091	Accuracy: 0.981/0.974

# %%
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.title('Loss')
plt.plot(ts_t, label='Norm')
plt.plot(ts_t_r, label='Rotation')
plt.plot(ts_t_a, label='Affine')
plt.plot(ts_t_n, label='Noise')
plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Loss', fontsize=16)
plt.legend(loc=0, fontsize=16)
plt.grid()
plt.subplot(1, 2, 2)
plt.title('Accuracy')
plt.plot(ts_ac_t, label='Norm')
plt.plot(ts_ac_t_r, label='Rotation')
plt.plot(ts_ac_t_a, label='Affine')
plt.plot(ts_ac_t_n, label='Noise')
plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Loss', fontsize=16)
plt.legend(loc=0, fontsize=16)
plt.grid()
plt.show()

# %% [markdown]
# Вращение и сдвиг:

# %%
transform = transforms.Compose([
                       transforms.RandomRotation((-15, 15)),
                       transforms.RandomAffine(0, translate=(0.05, 0.05)),
                       transforms.ToTensor(),
                       transforms.Normalize((0.1307,), (0.3081,))
                    ])

train_dataset = MNIST('.', train=True, download=True, transform=transform)
test_dataset = MNIST('.', train=False, transform=transform)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=True)

network = NeuralNetwork([Linear(784, 100), TANH(),
               Linear(100, 100), TANH(),
               Linear(100, 10)])
loss = NLLLoss()

tr_t_r_a, ts_t_r_a, tr_ac_t_r_a, ts_ac_t_r_a = train(network, 20, 0.01)
# Out:
# Epoch 19... (Train/Test) NLL: 0.100/0.096	Accuracy: 0.969/0.970

# %% [markdown]
# Вращение и шум:

# %%
transform = transforms.Compose([
                       transforms.RandomRotation((-15, 15)),
                       transforms.ToTensor(),
                       transforms.Normalize((0.1307,), (0.3081,))
                    ] + [noise])

train_dataset = MNIST('.', train=True, download=True, transform=transform)
test_dataset = MNIST('.', train=False, transform=transform)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=True)

network = NeuralNetwork([Linear(784, 100), TANH(),
               Linear(100, 100), TANH(),
               Linear(100, 10)])
loss = NLLLoss()

tr_t_r_n, ts_t_r_n, tr_ac_t_r_n, ts_ac_t_r_n = train(network, 20, 0.01)
# Out:
# Epoch 19... (Train/Test) NLL: 0.102/0.111	Accuracy: 0.969/0.966

# %% [markdown]
# Сдвиг и Шум:

# %%
transform = transforms.Compose([
                       transforms.RandomAffine(0, translate=(0.05, 0.05)),
                       transforms.ToTensor(),
                       transforms.Normalize((0.1307,), (0.3081,))
                    ] + [noise])

train_dataset = MNIST('.', train=True, download=True, transform=transform)
test_dataset = MNIST('.', train=False, transform=transform)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=True)

network = NeuralNetwork([Linear(784, 100), TANH(),
               Linear(100, 100), TANH(),
               Linear(100, 10)])
loss = NLLLoss()

tr_t_a_n, ts_t_a_n, tr_ac_t_a_n, ts_ac_t_a_n = train(network, 20, 0.01)
# Out:
# Epoch 19... (Train/Test) NLL: 0.099/0.092	Accuracy: 0.971/0.972

# %% [markdown]
# Вращение, шум и сдивг:

# %%
transform = transforms.Compose([
                       transforms.RandomRotation((-15, 15)),
                       transforms.RandomAffine(0, translate=(0.05, 0.05)),
                       transforms.ToTensor(),
                       transforms.Normalize((0.1307,), (0.3081,))
                    ] + [noise])

train_dataset = MNIST('.', train=True, download=True, transform=transform)
test_dataset = MNIST('.', train=False, transform=transform)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=True)

network = NeuralNetwork([Linear(784, 100), TANH(),
               Linear(100, 100), TANH(),
               Linear(100, 10)])
loss = NLLLoss()

tr_t_a_n_r, ts_t_a_n_r, tr_ac_t_a_n_r, ts_ac_t_a_n_r = train(network, 20, 0.01)
# Out:
# Epoch 19... (Train/Test) NLL: 0.129/0.114	Accuracy: 0.962/0.965

# %%
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.title('Loss')
plt.plot(ts_t, label='Norm')
plt.plot(ts_t_r_a, label='Rotation/Affine')
plt.plot(ts_t_r_n, label='Rotation/Noise')
plt.plot(ts_t_a_n, label='Affine/Noise')
plt.plot(ts_t_a_n_r, label='Affine/Noise/Rotation')
plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Loss', fontsize=16)
plt.legend(loc=0, fontsize=16)
plt.grid()
plt.subplot(1, 2, 2)
plt.title('Accuracy')
plt.plot(ts_ac_t, label='Norm')
plt.plot(ts_ac_t_r_a, label='Rotation/Affine')
plt.plot(ts_ac_t_r_n, label='Rotation/Noise')
plt.plot(ts_ac_t_a_n, label='Affine/Noise')
plt.plot(ts_ac_t_a_n_r, label='Affine/Noise/Rotation')
plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Loss', fontsize=16)
plt.legend(loc=0, fontsize=16)
plt.grid()
plt.show()

# %% [markdown]
# Обучите нейронную сеть с другими нелинейностями: ReLU и ELU. Сравните скорости сходимости и качество классификации с различными функциями активации.

# %%
transform = transforms.Compose([
                       transforms.ToTensor(),
                       transforms.Normalize((0.1307,), (0.3081,))
                    ])

train_dataset = MNIST('.', train=True, download=True, transform=transform)
test_dataset = MNIST('.', train=False, transform=transform)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=True)

network = NeuralNetwork([Linear(784, 100), TANH(),
               Linear(100, 100), TANH(),
               Linear(100, 10)])
loss = NLLLoss()

tr_t, ts_t, tr_ac_t, ts_ac_t = train(network, 20, 0.01, plot=False, verbose=False)

# %%
transform = transforms.Compose([
                       transforms.ToTensor(),
                       transforms.Normalize((0.1307,), (0.3081,))
                    ])

train_dataset = MNIST('.', train=True, download=True, transform=transform)
test_dataset = MNIST('.', train=False, transform=transform)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=True)

network = NeuralNetwork([Linear(784, 100), ELU(),
               Linear(100, 100), ELU(),
               Linear(100, 10)])
loss = NLLLoss()

tr_e, ts_e, tr_ac_e, ts_ac_e = train(network, 20, 0.01, plot=False, verbose=False)

# %%
transform = transforms.Compose([
                       transforms.ToTensor(),
                       transforms.Normalize((0.1307,), (0.3081,))
                    ])

train_dataset = MNIST('.', train=True, download=True, transform=transform)
test_dataset = MNIST('.', train=False, transform=transform)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=True)

network = NeuralNetwork([Linear(784, 100), ReLU(),
               Linear(100, 100), ReLU(),
               Linear(100, 10)])
loss = NLLLoss()

tr_r, ts_r, tr_ac_r, ts_ac_r = train(network, 20, 0.01, plot=False, verbose=False)

# %%
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.title('Loss')
plt.plot(ts_t, label='TANH')
plt.plot(ts_e, label='ELU')
plt.plot(ts_r, label='ReLU')

plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Loss', fontsize=16)
plt.legend(loc=0, fontsize=16)
plt.grid()
plt.subplot(1, 2, 2)
plt.title('Accuracy')
plt.plot(ts_ac_t, label='TANH')
plt.plot(ts_ac_e, label='ELU')
plt.plot(ts_ac_r, label='ReLU')
plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Loss', fontsize=16)
plt.legend(loc=0, fontsize=16)
plt.grid()
plt.show()

# %% [markdown]
# ### Часть 5: Выводы
# Опишите полученные результаты: как влияют выбор нелинейности и предобработка данных на скорость сходимости и итоговое качество?

# %% [markdown]
# TANH и ReLU примерно одинаковы по скорости сходимости и качеству, ELU немного уступает по качеству, хотя при большом количестве эпох, будет таким же.

# %% [markdown]
# Аугментация "сдвиг" хуже всего влияет на результат, "вращение" показывает наилучшие результаты, но все ранво, по сравнению с первоначальными данными без обработки, становится хуже.
# При комбинации аугментаций уменьшается скорость сходимости, но итоговое качества остается примерно таким же как и на данных без предобработки. При аугментации увеличивается количество данных, кажется, не всегда это разумно.
